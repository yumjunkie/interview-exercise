# %% [markdown]
# # Introduction - Problem Statement & Approach
#
# This Jupyter Notebook processes [Emergency Veterinarian Notification Services (EVNS) data](https://docs.google.com/spreadsheets/d/1AQ0L7I1yKA0zCpOyCj6lsf0kiLRLlEDKetUaZGnriqg/edit?usp=sharing).
#
# It will:
# 1. Load sample data from the provided Excel file into a PostgreSQL database on AWS.
# 2. Explore sample data.
# 3. Run SQL query to generate the emergency alert data format.
# 4. Use Python to filter results based on the `Vet Targets` file and output the final processed data file.
#
# #### Assumptions:
#
# a. The `VETS` table is our source-of-truth (being internal, verified data), and missing vet data should be backfilled from `EXTERNAL_VET_DATA` which is our second-best source-of-truth.
#
# b. We are only able to contact users from the `VETS` table.

# %% [markdown]
# # Key Takeaways
#
# * The final output file has 47 records, 36 unique vet IDs, and 4 records missing city and state.
# * "None" and "Other" specialties are included since the "Vet Targets" list likely came from a client who knows exactly who they want to target, regardless of the specialty we have on file. It would be good to confirm with stakeholders how they would like to handle this case going forward.
# * It appears that the `vet_id` field from the `VET` table is the most accurate and should be matched to the target file.
# * Some records in `VET_INFO` and `VET` tables have `NaN` values for critical fields such as `vet_id`, `first_name`, `last_name`, and `specialty`, which may impact analyses requiring a complete dataset.
# * The various zip code values are sometimes missing or unpadded. (They don't seem to match city/state, either, but I assume it's the nature of the synthetic data for this assignment).
#
# ## Recommended Next Steps
#
#
# * Explore backfill methods in the `VET` table for critical fields (i.e. `vet_id`, `zip_code`, `specialty`).
# * Deduplicate records where necessary, especially in `VET` and `VET_INFO` tables. (Note: If a user has more than one `vet_id`, then we can add a `primary` field to associate with their "best" ID. This will help ensure consistency with targeting and any ROI studies focusing on Rx lift.)
# * Productionalize pipeline by automating data ingestion, validation, and transformation using scheduled ETL processes, enforcing schema consistency, and implementing monitoring to detect missing or inconsistent data in real time.

# %%
# %pip install psycopg2
# %pip install pandas
# %pip install openpyxl
# %pip install sqlalchemy
# Out:
# Requirement already satisfied: psycopg2 in /Users/laurenchristopher/.local/pipx/venvs/jupyter/lib/python3.13/site-packages (2.9.10)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /Users/laurenchristopher/.local/pipx/venvs/jupyter/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /Users/laurenchristopher/.local/pipx/venvs/jupyter/lib/python3.13/site-packages (from pandas) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/laurenchristopher/.local/pipx/venvs/jupyter/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/laurenchristopher/.local/pipx/venvs/jupyter/lib/python3.13/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/laurenchristopher/.local/pipx/venvs/jupyter/lib/python3.13/site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /Users/laurenchristopher/.local/pipx/venvs/jupyter/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: openpyxl in /Users/laurenchristopher/.local/pipx/venvs/jupyter/lib/python3.13/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /Users/laurenchristopher/.local/pipx/venvs/jupyter/lib/python3.13/site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: sqlalchemy in /Users/laurenchristopher/.local/pipx/venvs/jupyter/lib/python3.13/site-packages (2.0.38)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/laurenchristopher/.local/pipx/venvs/jupyter/lib/python3.13/site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/laurenchristopher/.local/pipx/venvs/jupyter/lib/python3.13/site-packages (from sqlalchemy) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import psycopg2
from sqlalchemy import Integer, Boolean, String, UUID, BigInteger, DateTime, create_engine
from IPython.display import display

# %% [markdown]
# # 1. Load sample data from the provided Excel file into a PostgreSQL database on AWS.

# %%
# Load Excel file with multiple sheets
file_path = "~/Downloads/MDCalc_Data_Exercise.xlsx"
sheets = pd.ExcelFile(file_path)

# Define a converter function for "do_not_sell" since Pandas is misinterpreting it
def bool_converter(value):
    if isinstance(value, bool):  # If already a boolean, keep it
        return value
    if str(value).strip().lower() in ["false", "0", "no"]:  # Standardize false values
        return False
    if str(value).strip().lower() in ["true", "1", "yes"]:  # Standardize true values
        return True
    return None  # Handle empty or unexpected values

# Define correct data types for each sheet (EXCLUDING "do_not_sell")
dtype_mapping = {
    "vet_id": "Int64",  # Ensures integer storage, allows NaNs
    "uuid": "string",  # Keep UUIDs as strings
    "vet_id_source": "string",
    "first_name": "string",
    "last_name": "string",
    "zip": "string",
    "zip_code": "string",
    "specialty": "string",
    "address": "string",
    "city": "string",
    "state": "string",
    "publisher_deal_id": "string", #Although this is BigInt in data dictionary, values should be text as they contain a dash
    "event": "string",
}

# Load specific sheets into DataFrames with enforced data types
vet_targets_data = sheets.parse("Vet Targets", dtype=dtype_mapping)
vet_info_data = sheets.parse("vet_info", dtype=dtype_mapping, converters={"do_not_sell": bool_converter})
vet_data = sheets.parse("vet", dtype=dtype_mapping)
vet_emergency_alerts_log_data = sheets.parse(
    "vet_emergecy_alerts_log", dtype=dtype_mapping, parse_dates=["timestamp"]
)  
vet_emergency_subscription_data = sheets.parse("vet_emergency_subscription", dtype=dtype_mapping)
external_vet_data_data = sheets.parse("external_vet_data", dtype=dtype_mapping)


# Preview datatypes
print("\n--- Vet Targets Data Types ---\n", vet_targets_data.dtypes)
print("\n--- Vet Info Data Types ---\n", vet_info_data.dtypes)
print("\n--- Vet Data Types ---\n", vet_data.dtypes)
print("\n--- Vet Emergency Alerts Log Data Types ---\n", vet_emergency_alerts_log_data.dtypes)
print("\n--- Vet Emergency Subscription Data Types ---\n", vet_emergency_subscription_data.dtypes)
print("\n--- External Vet Data Types ---\n", external_vet_data_data.dtypes)

# Preview data
print("\n--- Vet Targets Data Preview ---\n", vet_targets_data.head())
print("\n--- Vet Info Data Preview ---\n", vet_info_data.head())
print("\n--- Vet Data Preview ---\n", vet_data.head())
print("\n--- Vet Emergency Alerts Log Data Preview ---\n", vet_emergency_alerts_log_data.head())
print("\n--- Vet Emergency Subscription Data Preview ---\n", vet_emergency_subscription_data.head())
print("\n--- External Vet Data Preview ---\n", external_vet_data_data.head())
# Out:
# --- Vet Targets Data Types ---
#  vet_id    Int64
# dtype: object
#
# --- Vet Info Data Types ---
#  uuid             string[python]
# vet_id                    Int64
# vet_id_source    string[python]
# do_not_sell                bool
# dtype: object
#
# --- Vet Data Types ---
#  uuid          string[python]
# vet_id                 Int64
# first_name    string[python]
# last_name     string[python]
# zip_code      string[python]
# specialty     string[python]
# dtype: object
#
# --- Vet Emergency Alerts Log Data Types ---
#  uuid                                    string[python]
# vet_emergency_subscription_uuid                 object
# vet_uuid                                        object
# event                                   string[python]
# timestamp                          datetime64[ns, UTC]
# dtype: object
#
# --- Vet Emergency Subscription Data Types ---
#  uuid                 string[python]
# subscription_name            object
# publisher                    object
# publisher_deal_id    string[python]
# dtype: object
#
# --- External Vet Data Types ---
#  vet_id                 Int64
# first_name    string[python]
# last_name     string[python]
# zip           string[python]
# address       string[python]
# city          string[python]
# state         string[python]
# specialty     string[python]
# dtype: object
#
# --- Vet Targets Data Preview ---
#         vet_id
# 0  1346411829
# 1  1407380601
# 2  1184003053
# 3  1730144367
# 4  1780750081
#
# --- Vet Info Data Preview ---
#                                     uuid      vet_id vet_id_source  do_not_sell
# 0  cdaff8e5-b977-4b22-88e3-8431fb495732  1932125259      verified        False
# 1  f59b6df8-eeaf-fc03-2ded-d8658752dcff  1972068484      verified        False
# 2  f36568dd-4187-400c-b0b4-497db667c2b2  1104353424      verified        False
# 3  ac2b7bdc-7306-4203-ba54-ab0e74566403  1104820133      verified        False
# 4  34a9cbc1-4899-4d4f-8922-fbe4d9978b57  1053413443      verified        False
#
# --- Vet Data Preview ---
#                                     uuid      vet_id first_name last_name  \
# 0  c9efa4a5-90ff-424c-a5b2-ebe2931ce896        <NA>  Elizabeth      Rhee
# 1  fe8da677-003f-4c2d-8225-e3fb426ff789    12850960  Elizabeth      Than
# 2  f471f141-2775-4a3d-9724-363e2cc6bdaf  1861019942    Rasendu   Metzger
# 3  f43d8cac-6878-4df6-94cf-d840d2b2eaea  1841722837    Mallory  shrestha
# 4  a809ae80-0285-4b62-a046-872373b0cde4  1366420817    Hampton      Goel
#
#   zip_code          specialty
# 0    33030  Canine and Feline
# 1    77539  Canine and Feline
# 2    30068  Canine and Feline
# 3    11434  Canine and Feline
# 4    32608               <NA>
#
# --- Vet Emergency Alerts Log Data Preview ---
#                                     uuid       vet_emergency_subscription_uuid  \
# 0  7563fd32-3b59-45b3-b531-a5b075101459  2c45e2a2-ce49-49b7-a683-1fba9953470a
# 1  2ad09998-9aee-4efc-8a11-f7fa11f47271  a8964332-412b-4828-9b4b-a6943010f5f5
# 2  de8631ff-e071-406a-89e6-5dd69237b631  295cc93f-2421-48d8-a0c5-c36068ae1e7d
# 3  e3a1ae1b-6ac8-4408-bb20-ea6831d457e3  295cc93f-2421-48d8-a0c5-c36068ae1e7d
# 4  fff9953d-f820-4ffe-9d41-91ca7261b924  2c45e2a2-ce49-49b7-a683-1fba9953470a
#
#                                vet_uuid     event  \
# 0  c6c1621a-0e73-49f7-a82a-50ef25a2bdbf  rejected
# 1  c6c1621a-0e73-49f7-a82a-50ef25a2bdbf  notified
# 2  9def5d81-b024-4ded-8cd2-1fd2d58b22c2  rejected
# 3  9def5d81-b024-4ded-8cd2-1fd2d58b22c2  notified
# 4  deebde90-a479-2b6f-aec1-d3f37418686c  notified
#
#                          timestamp
# 0 2025-02-16 05:20:41.105267+00:00
# 1 2025-02-16 05:20:37.876503+00:00
# 2 2025-02-16 00:30:00.028978+00:00
# 3 2025-02-16 00:29:56.236750+00:00
# 4 2025-02-14 03:05:36.716018+00:00
#
# --- Vet Emergency Subscription Data Preview ---
#                                     uuid subscription_name  \
# 0  295cc93f-2421-48d8-a0c5-c36068ae1e7d         EM_VETS_1
# 1  1e5b3700-58e0-4218-8cc9-0f1b9dea3b25         EM_VETS_2
# 2  9998c60b-5e78-4085-a02a-41f0fe105735         EM_VETS_3
# 3  aeffaaf8-68d1-4782-a6c7-97eb450ca02f         EM_VETS_4
# 4  3d6205af-c194-451e-b6ab-ae9e42d03afc         EM_VETS_5
#
#              publisher publisher_deal_id
# 0      EM Vets Atlanta      14582726-100
# 1     EM Vets New York      14582726-101
# 2  EM Vets Los Angeles      14582726-102
# 3       EM Vets Dallas      14582726-103
# 4      EM Vets Orlando      14582726-104
#
# --- External Vet Data Preview ---
#         vet_id first_name last_name    zip                address  \
# 0  1861019999  Elizabeth      Rhee  33030       2215 Burdett Ave
# 1    12850960  Elizabeth      Than  77539         2351 E 22nd St
# 2  1861019942    Rasendu   Metzger  30068  1906 Belleview Ave SE
# 3  1841722837    Mallory  shrestha  11434      4220 Harding Pike
# 4  1366420817    Hampton      Goel  32608         1325 Spring St
#
#            city state          specialty
# 0      Danville    PA  Canine and Feline
# 1   Rock Island    IL  Canine and Feline
# 2        Duluth    GA  Canine and Feline
# 3  Mount Vernon    WA  Canine and Feline
# 4     San Diego    CA  Canine and Feline

# %%
# Connect to database

# Credentials
USER = "postgres"
PASSWORD = "$mdcalc!" # Hardcoding passwords is a security risk, and I would use environment variables in a real scenario. 
AWS_ENDPOINT = "mydbinstance.cnuuqekuqqgd.us-west-2.rds.amazonaws.com"
PORT = "5432"
DATABASE = "data_exercises"

# Use SSL (since AWS enforces it)
DATABASE_URL = f"postgresql://{USER}:{PASSWORD}@{AWS_ENDPOINT}:{PORT}/{DATABASE}?sslmode=require"

# Create the database engine
engine = create_engine(DATABASE_URL)

# Test the connection
try:
    with engine.connect() as connection:
        print("Connected to AWS PostgreSQL successfully!")
except Exception as e:
    print("Error connecting to PostgreSQL:", e)
# Out:
# Connected to AWS PostgreSQL successfully!

# %%
# Load data into PostgreSQL with enforced data types
# NOTE: We are working with small amounts of data, so there is no need to chunk and insert in batches.

vet_targets_data.to_sql(
    "vet_targets", con=engine, if_exists="replace", index=False
)

vet_info_data.to_sql(
    "vet_info",
    con=engine,
    if_exists="replace",
    index=False,
    dtype={
        "uuid": UUID(),
        "vet_id": Integer(),
        "do_not_sell": Boolean(),
        "vet_id_source": String(25),
    }
)

vet_data.to_sql(
    "vet",
    con=engine,
    if_exists="replace",
    index=False,
    dtype={
        "uuid": UUID(),
        "vet_id": Integer(),
        "first_name": String(100),
        "last_name": String(100),
        "zip_code": String(100),
        "specialty": String(100),
    }
)

vet_emergency_alerts_log_data.to_sql(
    "vet_emergency_alerts_log",
    con=engine,
    if_exists="replace",
    index=False,
    dtype={
        "uuid": UUID(),
        "vet_uuid": UUID(),
        "vet_emergency_subscription_uuid": UUID(),
        "event": String(100),
        "event_timestamp": DateTime(timezone=True),
    }
)

vet_emergency_subscription_data.to_sql(
    "vet_emergency_subscription",
    con=engine,
    if_exists="replace",
    index=False,
    dtype={
        "uuid": UUID(),
        "subscription_name": String(100),
        "publisher": String(100),
        "publisher_deal_id": String(100),
    }
)

external_vet_data_data.to_sql(
    "external_vet_data",
    con=engine,
    if_exists="replace",
    index=False,
    dtype={
        "vet_id": Integer(),
        "first_name": String(100),
        "last_name": String(100),
        "address": String(100),
        "city": String(100),
        "state": String(100),
        "zip": String(100),
        "specialty": String(100),
    }
)

print("Data loaded successfully!")
# Out:
# Data loaded successfully!

# %% [markdown]
# # 2. EDA

# %%
# Check out new tables

# Print available tables
query = "SELECT table_name FROM information_schema.tables WHERE table_schema='public';"
tables = pd.read_sql(query, con=engine)
print("\n--- List of Tables in the Database ---\n", tables)

for table_name in tables["table_name"]:  # Extract table names correctly
    print(f"\n--- Structure of `{table_name}` ---\n")
    
    # Describe the table structure (column names & types)
    describe_query = f"SELECT column_name, data_type FROM information_schema.columns WHERE table_name = '{table_name}';"
    table_info = pd.read_sql(describe_query, con=engine)
    
    print(table_info)
# Out:
# --- List of Tables in the Database ---
#                     table_name
# 0                 vet_targets
# 1                    vet_info
# 2                         vet
# 3    vet_emergency_alerts_log
# 4  vet_emergency_subscription
# 5           external_vet_data
# 6     vet_emergecy_alerts_log
#
# --- Structure of `vet_targets` ---
#
#   column_name data_type
# 0      vet_id    bigint
#
# --- Structure of `vet_info` ---
#
#      column_name          data_type
# 0           uuid               uuid
# 1         vet_id            integer
# 2    do_not_sell            boolean
# 3  vet_id_source  character varying
#
# --- Structure of `vet` ---
#
#   column_name          data_type
# 0        uuid               uuid
# 1      vet_id            integer
# 2  first_name  character varying
# 3   last_name  character varying
# 4    zip_code  character varying
# 5   specialty  character varying
#
# --- Structure of `vet_emergency_alerts_log` ---
#
#                        column_name                 data_type
# 0                             uuid                      uuid
# 1  vet_emergency_subscription_uuid                      uuid
# 2                         vet_uuid                      uuid
# 3                        timestamp  timestamp with time zone
# 4                            event         character varying
#
# --- Structure of `vet_emergency_subscription` ---
#
#          column_name          data_type
# 0               uuid               uuid
# 1  subscription_name  character varying
# 2          publisher  character varying
# 3  publisher_deal_id  character varying
#
# --- Structure of `external_vet_data` ---
#
#   column_name          data_type
# 0      vet_id            integer
# 1  first_name  character varying
# 2   last_name  character varying
# 3         zip  character varying
# 4     address  character varying
# 5        city  character varying
# 6       state  character varying
# 7   specialty  character varying
#
# --- Structure of `vet_emergecy_alerts_log` ---
#
#                        column_name                 data_type
# 0                             uuid                      uuid
# 1  vet_emergency_subscription_uuid                      uuid
# 2                         vet_uuid                      uuid
# 3                        timestamp  timestamp with time zone
# 4                            event         character varying

# %%
#Vet Info
query = """
    SELECT 
        V.uuid AS vet_uuid,
        V.vet_id AS vet_vet_id,
        V.first_name,
        V.last_name,
        V.zip_code,
        V.specialty,
        VI.uuid AS vet_info_uuid,
        VI.vet_id AS vet_info_vet_id,
        VI.vet_id_source,
        VI.do_not_sell
    FROM VET V
    FULL OUTER JOIN VET_INFO VI 
    ON V.uuid = VI.uuid;
"""
int_vet_df = pd.read_sql(query, con=engine)
int_vet_df
# Out:
#                                  vet_uuid    vet_vet_id first_name last_name  \
# 0                                    None           NaN       None      None
# 1    f59b6df8-eeaf-fc03-2ded-d8658752dcff           NaN    Madison      Seda
# 2    f36568dd-4187-400c-b0b4-497db667c2b2  1.104353e+09     Saurav      Wash
# 3                                    None           NaN       None      None
# 4                                    None           NaN       None      None
# ..                                    ...           ...        ...       ...
# 509  f471f141-2775-4a3d-9724-363e2cc6bdaf  1.861020e+09    Rasendu   Metzger
# 510                                  None           NaN       None      None
# 511                                  None           NaN       None      None
# 512  9fcd99fe-f3be-453f-87bf-5c478e0f27be           NaN       Owen     Perez
# 513  46fde2c4-d787-4bdb-8d3d-2ef5ccf41833  1.588921e+09    Gabriel    Norton
#
#     zip_code          specialty                         vet_info_uuid  \
# 0       None               None  cdaff8e5-b977-4b22-88e3-8431fb495732
# 1       7070            Surgery  f59b6df8-eeaf-fc03-2ded-d8658752dcff
# 2       None  Canine and Feline  f36568dd-4187-400c-b0b4-497db667c2b2
# 3       None               None  ac2b7bdc-7306-4203-ba54-ab0e74566403
# 4       None               None  34a9cbc1-4899-4d4f-8922-fbe4d9978b57
# ..       ...                ...                                   ...
# 509    30068  Canine and Feline  f471f141-2775-4a3d-9724-363e2cc6bdaf
# 510     None               None  c6a8ce09-bace-44ca-b851-9e0681e5c471
# 511     None               None  1ff5679c-866a-409a-89e7-5d09287c9cec
# 512    20708               None  9fcd99fe-f3be-453f-87bf-5c478e0f27be
# 513    47304               None  46fde2c4-d787-4bdb-8d3d-2ef5ccf41833
#
#      vet_info_vet_id vet_id_source  do_not_sell
# 0         1932125259      verified        False
# 1         1972068484      verified        False
# 2         1104353424      verified        False
# 3         1104820133      verified        False
# 4         1053413443      verified        False
# ..               ...           ...          ...
# 509       1861019879      verified        False
# 510       1518260199      verified        False
# 511       1467422618      verified        False
# 512       1649314311      verified        False
# 513       1588920458      verified        False
#
# [514 rows x 10 columns]

# %%
# Count records that exist only in VET 
only_in_vet = int_vet_df[int_vet_df["vet_info_uuid"].isna()].shape[0]

# Count records that exist only in VET_INFO 
only_in_vet_info = int_vet_df[int_vet_df["vet_uuid"].isna()].shape[0]

# Count records that exist in BOTH VET and VET_INFO
in_both = int_vet_df[int_vet_df["vet_uuid"].notna() & int_vet_df["vet_info_uuid"].notna()].shape[0]

# Print results
print(f"Records only in VET: {only_in_vet}")
print(f"Records only in VET_INFO: {only_in_vet_info}")
print(f"Records in BOTH tables: {in_both}")

# ✅ Raise an error if in_both + only_in_vet_info is not 514
if in_both + only_in_vet_info != 514:
    raise ValueError("Error: The sum of 'in_both' and 'only_in_vet_info' is NOT 514, which is unexpected!")
# Out:
# Records only in VET: 0
# Records only in VET_INFO: 294
# Records in BOTH tables: 220

# %%
# Inspect records that are only in VET_INFO. 
only_in_vet_info_df = int_vet_df[int_vet_df["vet_uuid"].isna()]

# Are there verified vets that we can contact?
only_in_vet_pivot = only_in_vet_info_df.pivot_table(
    index=["do_not_sell", "vet_id_source"], 
    values="vet_uuid", 
    aggfunc="count"
)
only_in_vet_pivot
# Out:
#                            vet_uuid
# do_not_sell vet_id_source
# False       verified              0

# %% [markdown]
# *All missing vet details are associated with contactable vets, so it is worth trying to backfill.*

# %%
#Backfill missing data where available; prioritize data in `VETS` table. 

#Vet Info
backfill_query = """
    SELECT 
        VI.uuid, 
        VI.vet_id, 
        VI.vet_id_source,
        VI.do_not_sell, 
        COALESCE(V.first_name, EV.first_name) as first_name,
        COALESCE(V.last_name, EV.last_name) as last_name,
        EV.city,
        EV.state,
        COALESCE(V.zip_code, EV.zip) as zip,
        COALESCE(V.specialty, EV.specialty) as specialty
    FROM VET_INFO VI 
    LEFT JOIN VET V ON V.uuid = VI.uuid
    LEFT JOIN EXTERNAL_VET_DATA EV ON EV.vet_id = VI.vet_id;
"""
backfill_vet_df = pd.read_sql(backfill_query, con=engine)
backfill_vet_df
# Out:
#                                      uuid      vet_id vet_id_source  \
# 0    cdaff8e5-b977-4b22-88e3-8431fb495732  1932125259      verified
# 1    f59b6df8-eeaf-fc03-2ded-d8658752dcff  1972068484      verified
# 2    f36568dd-4187-400c-b0b4-497db667c2b2  1104353424      verified
# 3    ac2b7bdc-7306-4203-ba54-ab0e74566403  1104820133      verified
# 4    34a9cbc1-4899-4d4f-8922-fbe4d9978b57  1053413443      verified
# ..                                    ...         ...           ...
# 509  f471f141-2775-4a3d-9724-363e2cc6bdaf  1861019879      verified
# 510  c6a8ce09-bace-44ca-b851-9e0681e5c471  1518260199      verified
# 511  1ff5679c-866a-409a-89e7-5d09287c9cec  1467422618      verified
# 512  9fcd99fe-f3be-453f-87bf-5c478e0f27be  1649314311      verified
# 513  46fde2c4-d787-4bdb-8d3d-2ef5ccf41833  1588920458      verified
#
#      do_not_sell first_name last_name  city state    zip          specialty
# 0          False       None      None  None  None   None               None
# 1          False    Madison      Seda  None  None   7070            Surgery
# 2          False     Saurav      Wash  None  None   None  Canine and Feline
# 3          False       None      None  None  None   None               None
# 4          False       None      None  None  None   None               None
# ..           ...        ...       ...   ...   ...    ...                ...
# 509        False    Rasendu   Metzger  None  None  30068  Canine and Feline
# 510        False       None      None  None  None   None               None
# 511        False       None      None  None  None   None               None
# 512        False       Owen     Perez  None  None  20708               None
# 513        False    Gabriel    Norton  None  None  47304               None
#
# [514 rows x 10 columns]

# %%
# Count the number of null values in each column
null_counts = backfill_vet_df.isnull().sum()

# Convert to DataFrame for better readability
null_counts_df = pd.DataFrame(null_counts, columns=['null_count'])
null_counts_df
# Out:
#                null_count
# uuid                    0
# vet_id                  0
# vet_id_source           0
# do_not_sell             0
# first_name            294
# last_name             294
# city                  514
# state                 514
# zip                   302
# specialty             339

# %% [markdown]
# *The `EXTERNAL_VET_DATA` join is not pulling in any data. Let's see why this is.*

# %%
#Explore join issue 
root_cause_query = """
    SELECT 
        V.uuid AS vet_and_info_uuid,
        V.vet_id AS vet_vet_id,
        VI.vet_id AS info_vet_id,
        EV.vet_id AS external_vet_id
    FROM VET_INFO VI  
    LEFT JOIN VET V ON V.uuid = VI.uuid
    LEFT JOIN EXTERNAL_VET_DATA EV ON EV.vet_id = V.vet_id
    LEFT JOIN EXTERNAL_VET_DATA EV2 ON EV.vet_id = VI.vet_id
    --WHERE EV.vet_id = '12850960';
    WHERE V.vet_id != VI.vet_id OR EV.vet_id != VI.vet_id;
"""

root_cause_df = pd.read_sql(root_cause_query, con=engine)
root_cause_df
# Out:
#                         vet_and_info_uuid  vet_vet_id  info_vet_id  \
# 0    f36568dd-4187-400c-b0b4-497db667c2b2  1104353487   1104353424
# 1    93828087-26af-480f-8ebb-88b6bd815983    10851572   1063851509
# 2    f6356146-4325-4329-bf61-fa3050c90b43  1316924158   1316924095
# 3    e1e266a5-c3d4-493e-a8a3-d4247d456a33  1790924032   1790923969
# 4    cfd048f9-80d6-4f65-a2b0-a803823fd318  1093074333   1093074270
# ..                                    ...         ...          ...
# 176  b97ce303-9c15-4694-b89d-62ec5bcfc7fe  1912534658   1912534595
# 177  72858752-11ce-46e2-bc83-e92be53e1a9d  1013302278   1013302215
# 178  d018ba44-501e-76a7-6d88-c144c2906404  1538392176   1538392113
# 179  f471f141-2775-4a3d-9724-363e2cc6bdaf  1861019942   1861019879
# 180  46fde2c4-d787-4bdb-8d3d-2ef5ccf41833  1588920521   1588920458
#
#      external_vet_id
# 0         1104353487
# 1           10851572
# 2         1316924158
# 3         1790924032
# 4         1093074333
# ..               ...
# 176       1912534658
# 177       1013302278
# 178       1538392176
# 179       1861019942
# 180       1588920521
#
# [181 rows x 4 columns]

# %% [markdown]
# *As we can see above, the same vet UUID can be associated with different vet IDs. This does not appear to be a padding or rounding issue, but rather actual different values. If these were NPI numbers, I would find this very concerning. While it's true that a prescriber could have more than one NPI, it is not so common that I would so many records to point to different IDs. Let's explore some more to see what's going on here.*

# %%
# Check out duplicate and missing values 

def count_duplicates_and_missing(df, table_name, columns):
    """
    Counts duplicate and missing values for specific columns in a DataFrame.

    Args:
        df (pd.DataFrame): The DataFrame to analyze.
        table_name (str): Name of the table (for display purposes).
        columns (list): List of column names to check for duplicates and missing values.

    Returns:
        pd.DataFrame: A DataFrame showing duplicate and missing counts per column.
    """
    results = []
    
    for col in columns:
        if col in df.columns:
            duplicate_count = df[col].duplicated(keep=False).sum()
            missing_count = df[col].isna().sum()
            results.append({"Column": col, "Duplicate Count": duplicate_count, "Missing Count": missing_count})

    # Convert to DataFrame for display
    results_df = pd.DataFrame(results)

    # Display results
    print(f"\n--- {table_name} ---\n")
    display(results_df)

# Run the function for each table and display results
count_duplicates_and_missing(vet_data, "vet", ["vet_id", "uuid"])
count_duplicates_and_missing(vet_info_data, "vet_info", ["vet_id", "uuid"])
count_duplicates_and_missing(external_vet_data_data, "external_vet_data", ["vet_id"])
# Out:
# --- vet ---
#    Column  Duplicate Count  Missing Count
# 0  vet_id               39             39
# 1    uuid                0              0
# --- vet_info ---
#    Column  Duplicate Count  Missing Count
# 0  vet_id               10              0
# 1    uuid                0              0
# --- external_vet_data ---
#    Column  Duplicate Count  Missing Count
# 0  vet_id                2              0

# %%
# Does the external data match any vet_id values in the VET_INFO table? 
# Which join has the better match rate?

HELP_QUERY = """
    SELECT COUNT(DISTINCT VI.VET_ID) AS VI_VET_ID_MATCH_COUNT
    FROM VET_INFO VI 
    INNER JOIN VET_TARGETS VT ON VT.VET_ID = VI.VET_ID 
    UNION ALL 
    SELECT COUNT(DISTINCT V.VET_ID) AS V_VET_ID_MATCH_COUNT
    FROM VET V
    INNER JOIN VET_TARGETS VT ON VT.VET_ID = V.VET_ID
    """
HELP_QUERY_df = pd.read_sql(HELP_QUERY, con=engine)
HELP_QUERY_df
# Out:
#    vi_vet_id_match_count
# 0                      0
# 1                    105

# %% [markdown]
# *We see that some vet IDs are duplicated even though UUIDs are not, and we also see that no `vet_id` values from the `VET_INFO` table match the `VET_TARGETS` table. It is not clear what this `vet_id` value represents and what expectations are around matching. More work should be done to understand this ID issue. For this project, we will assume that the `vet_id` from the `VET` table is the most accurate and should be matched to the target file.*

# %%
# Incorporate new understanding into backfill query 

final_backfill_query = """
    SELECT 
        VI.uuid, 
        V.vet_id, -- no VI.vet_ids match the targeting file
        VI.vet_id_source,
        COALESCE(V.first_name, EV.first_name) as first_name,
        COALESCE(V.last_name, EV.last_name) as last_name,
        EV.city,
        EV.state,
        COALESCE(V.zip_code, EV.zip) as zip,
        COALESCE(V.specialty, EV.specialty) as specialty, 
        VI.do_not_sell
    FROM VET_INFO VI 
    LEFT JOIN VET V ON V.uuid = VI.uuid -- good join on foriegn keys
    LEFT JOIN EXTERNAL_VET_DATA EV ON EV.vet_id = V.vet_id -- assuming we can trust this join as most values align rather than VET_INFO
    ;
"""
final_backfill_vet_df = pd.read_sql(final_backfill_query, con=engine)
final_backfill_vet_df
# Out:
#                                      uuid        vet_id vet_id_source  \
# 0    cdaff8e5-b977-4b22-88e3-8431fb495732           NaN      verified
# 1    f59b6df8-eeaf-fc03-2ded-d8658752dcff           NaN      verified
# 2    f36568dd-4187-400c-b0b4-497db667c2b2  1.104353e+09      verified
# 3    ac2b7bdc-7306-4203-ba54-ab0e74566403           NaN      verified
# 4    34a9cbc1-4899-4d4f-8922-fbe4d9978b57           NaN      verified
# ..                                    ...           ...           ...
# 509  f471f141-2775-4a3d-9724-363e2cc6bdaf  1.861020e+09      verified
# 510  c6a8ce09-bace-44ca-b851-9e0681e5c471           NaN      verified
# 511  1ff5679c-866a-409a-89e7-5d09287c9cec           NaN      verified
# 512  9fcd99fe-f3be-453f-87bf-5c478e0f27be           NaN      verified
# 513  46fde2c4-d787-4bdb-8d3d-2ef5ccf41833  1.588921e+09      verified
#
#     first_name last_name      city state    zip          specialty  \
# 0         None      None      None  None   None               None
# 1      Madison      Seda      None  None   7070            Surgery
# 2       Saurav      Wash      None  None   None  Canine and Feline
# 3         None      None      None  None   None               None
# 4         None      None      None  None   None               None
# ..         ...       ...       ...   ...    ...                ...
# 509    Rasendu   Metzger    Duluth    GA  30068  Canine and Feline
# 510       None      None      None  None   None               None
# 511       None      None      None  None   None               None
# 512       Owen     Perez      None  None  20708               None
# 513    Gabriel    Norton  Portland    OR  47304  Canine and Feline
#
#      do_not_sell
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ..           ...
# 509        False
# 510        False
# 511        False
# 512        False
# 513        False
#
# [514 rows x 10 columns]

# %%
# Tie in events and subscription data

event_and_sub_query = """
    SELECT 
        V.uuid, 
        V.vet_id, -- no VI.vet_ids match the targeting file
        VI.vet_id_source,
        COALESCE(V.first_name, EV.first_name) as first_name,
        COALESCE(V.last_name, EV.last_name) as last_name,
        EV.city,
        EV.state,
        COALESCE(V.zip_code, EV.zip) as zip,
        COALESCE(V.specialty, EV.specialty) as specialty, 
        VI.do_not_sell, 
        AL.uuid as log_uuid,
        AL.event,
        AL.timestamp AS event_timestamp,
        ES.subscription_name, 
        ES.publisher, 
        ES.publisher_deal_id

    FROM VET_INFO VI 
    INNER JOIN VET V ON V.uuid = VI.uuid -- good join on foriegn keys
    LEFT JOIN EXTERNAL_VET_DATA EV ON EV.vet_id = V.vet_id -- assuming we can trust this join as most values align rather than VET_INFO
    INNER JOIN VET_EMERGENCY_ALERTS_LOG AL ON AL.vet_uuid = V.uuid
    INNER JOIN VET_EMERGENCY_SUBSCRIPTION ES on ES.uuid = AL.vet_emergency_subscription_uuid; 
    """

event_and_sub_df = pd.read_sql(event_and_sub_query, con=engine)
event_and_sub_df
# Out:
#                                      uuid        vet_id vet_id_source  \
# 0    26a94c8e-7f88-4da4-8631-a1b326706b7f           NaN      verified
# 1    26a94c8e-7f88-4da4-8631-a1b326706b7f           NaN      verified
# 2    f6356146-4325-4329-bf61-fa3050c90b43  1.316924e+09      verified
# 3    e1e266a5-c3d4-493e-a8a3-d4247d456a33  1.790924e+09      verified
# 4    bdb25f86-273f-4a76-a709-41795401c1d7           NaN      verified
# ..                                    ...           ...           ...
# 106  5453b1ec-3e0a-6748-593e-5d3a817540b5           NaN      verified
# 107  72858752-11ce-46e2-bc83-e92be53e1a9d  1.013302e+09      verified
# 108  72858752-11ce-46e2-bc83-e92be53e1a9d  1.013302e+09      verified
# 109  f471f141-2775-4a3d-9724-363e2cc6bdaf  1.861020e+09      verified
# 110  f471f141-2775-4a3d-9724-363e2cc6bdaf  1.861020e+09      verified
#
#     first_name last_name      city state    zip           specialty  \
# 0       Andrew        Ma      None  None   6850  Clinical pathology
# 1       Andrew        Ma      None  None   6850  Clinical pathology
# 2         Ebon   Ajibola  Columbus    OH  43004   Canine and Feline
# 3        Bruce  Calikyan    Auburn    CA  58104          Immunology
# 4      Heather     Chace      None  None  24060                None
# ..         ...       ...       ...   ...    ...                 ...
# 106     Robert     Smith      None  None  98292                None
# 107      Shawn    Suhrer      None  None  92354   Canine and Feline
# 108      Shawn    Suhrer      None  None  92354   Canine and Feline
# 109    Rasendu   Metzger    Duluth    GA  30068   Canine and Feline
# 110    Rasendu   Metzger    Duluth    GA  30068   Canine and Feline
#
#      do_not_sell                              log_uuid     event  \
# 0          False  0718c3cb-a900-4d6a-8d5b-f479ba445d41  notified
# 1          False  c5a12163-9f3e-46be-abca-e3f6542fcc80  rejected
# 2          False  da35ec1a-f097-4622-a692-0b10ed568830  notified
# 3          False  9e4692b9-337b-49ba-8342-c7376ad13629  notified
# 4          False  a7c44bce-34cb-42b2-a6ee-57c5967e6512  notified
# ..           ...                                   ...       ...
# 106        False  c5eb8d08-0b07-48fb-9145-728167f9c3f9  notified
# 107        False  46ca56ea-6f52-41eb-b21f-79a8da4a02bf  accepted
# 108        False  ccd409a5-f53f-419a-bed3-de4101851e64  notified
# 109        False  09132144-cdcc-4f49-82ef-408eb65c5c6d  rejected
# 110        False  2401e003-7bad-4f88-967e-d396b833151f  notified
#
#                      event_timestamp subscription_name           publisher  \
# 0   2025-02-16 19:06:58.729598+00:00        EM_VETS_12     EM Vets Chicago
# 1   2025-02-16 19:07:00.251189+00:00        EM_VETS_19   EM Vets Charlotte
# 2   2025-02-15 16:44:06.359610+00:00        EM_VETS_19   EM Vets Charlotte
# 3   2025-02-15 23:11:45.401655+00:00        EM_VETS_19   EM Vets Charlotte
# 4   2025-02-15 22:15:17.259836+00:00        EM_VETS_19   EM Vets Charlotte
# ..                               ...               ...                 ...
# 106 2025-02-15 16:20:57.882313+00:00        EM_VETS_19   EM Vets Charlotte
# 107 2025-02-15 21:33:27.630948+00:00        EM_VETS_17  EM Vets Washington
# 108 2025-02-15 21:33:26.739308+00:00         EM_VETS_1     EM Vets Atlanta
# 109 2025-02-14 18:46:23.864797+00:00         EM_VETS_4      EM Vets Dallas
# 110 2025-02-14 18:46:20.385985+00:00        EM_VETS_14   EM Vets Las Vegas
#
#     publisher_deal_id
# 0        14582726-111
# 1        14582726-118
# 2        14582726-118
# 3        14582726-118
# 4        14582726-118
# ..                ...
# 106      14582726-118
# 107      14582726-116
# 108      14582726-100
# 109      14582726-103
# 110      14582726-113
#
# [111 rows x 16 columns]

# %%
# QA: Double check for: duplicate vet/event pairs & bad specialties 

# Count Duplicates for `vet_id` and `log_uuid`
duplicate_pairs = event_and_sub_df.duplicated(subset=["vet_id", "log_uuid"], keep=False).sum()
print(f"Duplicate vet_id & LOG_UUID pairs: {duplicate_pairs}")

# Count Specialty Occurrences and compare to https://www.avma.org/education/veterinary-specialties
# TODO: scrape this website to avoid manual checks in the future
specialty_counts = event_and_sub_df["specialty"].value_counts(dropna=False).reset_index()
specialty_counts.columns = ["Specialty", "Count"]
print("\nSpecialty Value Counts:")
display(specialty_counts)
# Out:
# Duplicate vet_id & LOG_UUID pairs: 0
#
# Specialty Value Counts:
#                 Specialty  Count
# 0       Canine and Feline     67
# 1                  Equine     13
# 2                    None      7
# 3               Neurology      6
# 4             Beef cattle      4
# 5              Immunology      4
# 6                   Other      3
# 7      Clinical pathology      2
# 8                Virology      2
# 9   Reptile and amphibian      1
# 10           Epidemiology      1
# 11                Surgery      1

# %% [markdown]
# *While we don't see any duplication of logs by vet, we do have "None" and "Other" Specialty categories that are not listed in the veterinarian specialties link that was provided. Because I am not sure whether unknown and "other" specialties should be excluded, I am including them as I assume the "Vet Targets" list came from a client who knows exactly who they want to target, regardless of the specialty we have on file for that vet. It would be good to confirm with stakeholders how they would like to handle this case going forward.*

# %% [markdown]
# # 3. Run SQL query to generate the emergency alert data format.

# %%
#final query, with necessary columns and filtering

final_query = """
    SELECT  
        V.vet_id, -- no VI.vet_ids match the targeting file
        COALESCE(V.first_name, EV.first_name) as first_name,
        COALESCE(V.last_name, EV.last_name) as last_name,
        EV.city,
        EV.state,
        COALESCE(V.zip_code, EV.zip) as zip,
        COALESCE(V.specialty, EV.specialty) as specialty, 
        VI.do_not_sell, 
        AL.event,
        AL.timestamp AS event_timestamp,
        ES.subscription_name, 
        ES.publisher, 
        ES.publisher_deal_id
    FROM VET_INFO VI 
    INNER JOIN VET V ON V.uuid = VI.uuid -- good join on foriegn keys
    LEFT JOIN EXTERNAL_VET_DATA EV ON EV.vet_id = V.vet_id -- assuming we can trust this join as most values align rather than VET_INFO
    INNER JOIN VET_EMERGENCY_ALERTS_LOG AL ON AL.vet_uuid = V.uuid
    INNER JOIN VET_EMERGENCY_SUBSCRIPTION ES on ES.uuid = AL.vet_emergency_subscription_uuid
    WHERE V.VET_ID IS NOT NULL -- final targeting file has to match VET_TARGETS which only has vet_id
        AND lower(trim(VI.vet_id_source)) = 'verified'
        AND do_not_sell != TRUE
    ORDER BY AL.timestamp
    ; 
    """

final_df = pd.read_sql(final_query, con=engine)
final_df
# Out:
#         vet_id first_name  last_name           city state    zip  \
# 0   1649685096    Zhiyuan    Fogarty           None  None  10305
# 1   1770013399          C  Pachinger        Augusta    GA  98908
# 2   1508328085      Pearl    Zghouzi  San Francisco    CA   2911
# 3   1972000673    Marilyn   Ceballos          Ocoee    FL  24018
# 4   1578068694      Renee        Ong        Tamarac    FL  15601
# ..         ...        ...        ...            ...   ...    ...
# 88  1205153926        Tom      Javed           None  None  10701
# 89  1346737554      Levon     Aquino          Bronx    NY  30032
# 90  1477917313    Stanley      Miner           None  None  45215
# 91  1477917313    Stanley      Miner           None  None  45215
# 92  1477917313    Stanley      Miner           None  None  45215
#
#             specialty  do_not_sell     event                  event_timestamp  \
# 0   Canine and Feline        False  notified 2025-02-14 00:03:51.160376+00:00
# 1   Canine and Feline        False  notified 2025-02-14 00:17:59.865480+00:00
# 2   Canine and Feline        False  notified 2025-02-14 01:10:37.622922+00:00
# 3   Canine and Feline        False  notified 2025-02-14 03:05:36.716018+00:00
# 4   Canine and Feline        False  notified 2025-02-14 03:27:00.272145+00:00
# ..                ...          ...       ...                              ...
# 88             Equine        False  notified 2025-02-16 17:05:01.909736+00:00
# 89  Canine and Feline        False  notified 2025-02-16 17:34:09.642603+00:00
# 90  Canine and Feline        False  rejected 2025-02-16 18:40:50.900371+00:00
# 91  Canine and Feline        False  notified 2025-02-16 18:40:50.919789+00:00
# 92  Canine and Feline        False  rejected 2025-02-16 18:40:51.025711+00:00
#
#    subscription_name          publisher publisher_deal_id
# 0         EM_VETS_19  EM Vets Charlotte      14582726-118
# 1          EM_VETS_1    EM Vets Atlanta      14582726-100
# 2          EM_VETS_1    EM Vets Atlanta      14582726-100
# 3         EM_VETS_12    EM Vets Chicago      14582726-111
# 4         EM_VETS_19  EM Vets Charlotte      14582726-118
# ..               ...                ...               ...
# 88         EM_VETS_4     EM Vets Dallas      14582726-103
# 89        EM_VETS_13    EM Vets Detroit      14582726-112
# 90        EM_VETS_14  EM Vets Las Vegas      14582726-113
# 91        EM_VETS_13    EM Vets Detroit      14582726-112
# 92         EM_VETS_4     EM Vets Dallas      14582726-103
#
# [93 rows x 13 columns]

# %% [markdown]
# # 4. Use Python to filter results based on the `Vet Targets` file and output the final processed data file.

# %%
# Generate final output file

# Load vet_targets to filter final_df
vet_targets_query = "SELECT vet_id FROM VET_TARGETS"
vet_targets_df = pd.read_sql(vet_targets_query, con=engine)

# Convert to a set for deduplication and fast filtering
vet_target_ids = set(vet_targets_df["vet_id"].dropna().astype(str)) 

# Filter final_df for vet_ids that exist in vet_targets
final_filtered_df = final_df[final_df["vet_id"].astype(str).isin(vet_target_ids)]

# Fix ZIP codes: Convert to string and pad with leading zeros
# NOTE: I noticed these zip codes don't align with the city/state. I am assuming the data is fake as opposed to problematic, 
#       and have not addressed zip issues in this notebook.
if "zip" in final_filtered_df.columns:
    final_filtered_df.loc[:, "zip"] = final_filtered_df["zip"].astype(str).str.zfill(5)

# Sort by event_timestamp
final_filtered_df = final_filtered_df.sort_values(by="event_timestamp")

# Save as a pipe (`|`) delimited file
output_file = "~/Downloads/vet_emergency_alerts_for_targets.txt"
final_filtered_df.to_csv(output_file, sep="|", index=False)

# Confirm file is saved
print(f"File saved successfully: {output_file}")
final_filtered_df
# Out:
# File saved successfully: ~/Downloads/vet_emergency_alerts_for_targets.txt
#         vet_id  first_name   last_name            city state    zip  \
# 0   1649685096     Zhiyuan     Fogarty            None  None  10305
# 1   1770013399           C   Pachinger         Augusta    GA  98908
# 2   1508328085       Pearl     Zghouzi   San Francisco    CA  02911
# 4   1578068694       Renee         Ong         Tamarac    FL  15601
# 5   1174025710  Aravindhan       Naeem     Sioux Falls    SD  67601
# 6   1174025710  Aravindhan       Naeem     Sioux Falls    SD  67601
# 7   1164650311        Brij       Adams        Clairton    PA  85118
# 8   1164650311        Brij       Adams        Clairton    PA  85118
# 9   1326508777      Justin        Jama   Staten Island    NY  70817
# 10  1326508777      Justin        Jama   Staten Island    NY  70817
# 11  1730136694      Robert        Roos        Prescott    AZ  07641
# 12  1184183532        Omar    Deidrick       Lancaster    PA  78541
# 13  1184183532        Omar    Deidrick       Lancaster    PA  78541
# 14  1285179594     Susmita   arvanitis      Washington    DC  48811
# 16  1508361070    Jennifer      Gurung        Winfield    IL  25271
# 17  1508361070    Jennifer      Gurung        Winfield    IL  25271
# 22  1225178888      Andrea      Sarani         Jamaica    NY  30045
# 23  1225178888      Andrea      Sarani         Jamaica    NY  30045
# 30  1174798165    Jennifer    Chandler         Atlanta    GA  84112
# 34  1013106012      Yihong       tully      South Bend    IN  70115
# 35  1013106012      Yihong       tully      South Bend    IN  70115
# 36  1275501882     Comfort    Jernigan      Southfield    MI  27615
# 37  1275501882     Comfort    Jernigan      Southfield    MI  27615
# 38  1558855830       nikee       Patel     Baton Rouge    LA  14621
# 41  1306849878       steve     Minikes    Indianapolis    IN  91367
# 44  1124058662       Iryna       Acres            None  None  60187
# 51  1053389805      NILESH      Idrees          Seneca    SC  48038
# 53  1740786834      Rajesh   Chhatkuli         Detroit    MI  83854
# 57  1316924158        Ebon     Ajibola        Columbus    OH  43004
# 58  1417453206      Carlos        Taza    Saint Joseph    MI  06032
# 59  1255489801      Haklai    Beaudoin   State College    PA  72404
# 62  1003831773        zaid         Lau        Torrance    CA  33511
# 63  1205000945     Antonio       Mason            None  None  48126
# 64  1275862513      Kelsey     Engwall        Johnston    RI  10940
# 65  1558827681      Adonis    khoshbin         Memphis    TN  90049
# 70  1790924032       Bruce    Calikyan          Auburn    CA  58104
# 75  1780750081       Danny     Becerra         Phoenix    AZ  19612
# 76  1780750081       Danny     Becerra         Phoenix    AZ  19612
# 79  1952783834       Megan        Mack   San Francisco    CA  44145
# 80  1164943789    Veronica     Karisny  Virginia Beach    VA  12208
# 81  1164943789    Veronica     Karisny  Virginia Beach    VA  12208
# 82    16699794    TEWODROS      Shahid     Grand Blanc    MI  33872
# 83    16699794    TEWODROS      Shahid     Grand Blanc    MI  33872
# 84  1326684810       Diana     Goodman          Tacoma    WA  30329
# 85  1053814893       Zarwa      Haddad            None  None  72223
# 86  1346411829    Victoria  Niyamuddin           Akron    OH  60607
# 89  1346737554       Levon      Aquino           Bronx    NY  30032
#
#             specialty  do_not_sell     event                  event_timestamp  \
# 0   Canine and Feline        False  notified 2025-02-14 00:03:51.160376+00:00
# 1   Canine and Feline        False  notified 2025-02-14 00:17:59.865480+00:00
# 2   Canine and Feline        False  notified 2025-02-14 01:10:37.622922+00:00
# 4   Canine and Feline        False  notified 2025-02-14 03:27:00.272145+00:00
# 5   Canine and Feline        False  notified 2025-02-14 03:37:11.175557+00:00
# 6   Canine and Feline        False  accepted 2025-02-14 03:37:20.990314+00:00
# 7              Equine        False  notified 2025-02-14 04:37:34.157688+00:00
# 8              Equine        False  rejected 2025-02-14 04:37:36.074911+00:00
# 9   Canine and Feline        False  notified 2025-02-14 08:20:34.248617+00:00
# 10  Canine and Feline        False  rejected 2025-02-14 08:20:36.684706+00:00
# 11  Canine and Feline        False  notified 2025-02-14 11:30:00.905017+00:00
# 12  Canine and Feline        False  notified 2025-02-14 13:49:09.278530+00:00
# 13  Canine and Feline        False  rejected 2025-02-14 13:49:11.447402+00:00
# 14           Virology        False  notified 2025-02-14 13:57:35.268325+00:00
# 16  Canine and Feline        False  notified 2025-02-14 14:38:43.432861+00:00
# 17  Canine and Feline        False  accepted 2025-02-14 14:38:44.297328+00:00
# 22  Canine and Feline        False  notified 2025-02-14 16:31:10.851095+00:00
# 23  Canine and Feline        False  notified 2025-02-14 16:32:31.518588+00:00
# 30         Immunology        False  notified 2025-02-14 17:26:05.267321+00:00
# 34  Canine and Feline        False  notified 2025-02-14 20:40:14.172764+00:00
# 35  Canine and Feline        False  rejected 2025-02-14 20:40:24.114280+00:00
# 36  Canine and Feline        False  notified 2025-02-14 21:43:31.379185+00:00
# 37  Canine and Feline        False  rejected 2025-02-14 21:43:34.452630+00:00
# 38  Canine and Feline        False  notified 2025-02-14 21:58:09.905076+00:00
# 41  Canine and Feline        False  notified 2025-02-14 23:46:13.232644+00:00
# 44        Beef cattle        False  notified 2025-02-15 00:31:34.095900+00:00
# 51             Equine        False  notified 2025-02-15 13:37:16.987809+00:00
# 53  Canine and Feline        False  notified 2025-02-15 16:20:43.535610+00:00
# 57  Canine and Feline        False  notified 2025-02-15 16:44:06.359610+00:00
# 58  Canine and Feline        False  notified 2025-02-15 16:48:46.649477+00:00
# 59             Equine        False  notified 2025-02-15 18:46:27.223407+00:00
# 62  Canine and Feline        False  notified 2025-02-15 19:11:47.906188+00:00
# 63         Immunology        False  notified 2025-02-15 19:23:06.608936+00:00
# 64  Canine and Feline        False  notified 2025-02-15 19:29:58.361423+00:00
# 65  Canine and Feline        False  notified 2025-02-15 20:19:41.970164+00:00
# 70         Immunology        False  notified 2025-02-15 23:11:45.401655+00:00
# 75             Equine        False  notified 2025-02-16 05:20:37.876503+00:00
# 76             Equine        False  rejected 2025-02-16 05:20:41.105267+00:00
# 79  Canine and Feline        False  notified 2025-02-16 09:06:30.433875+00:00
# 80  Canine and Feline        False  notified 2025-02-16 09:52:14.566632+00:00
# 81  Canine and Feline        False  rejected 2025-02-16 09:52:17.999909+00:00
# 82              Other        False  notified 2025-02-16 14:37:17.624695+00:00
# 83              Other        False  notified 2025-02-16 14:37:27.818208+00:00
# 84             Equine        False  notified 2025-02-16 14:39:20.751632+00:00
# 85              Other        False  notified 2025-02-16 15:35:46.551710+00:00
# 86  Canine and Feline        False  notified 2025-02-16 15:38:01.885586+00:00
# 89  Canine and Feline        False  notified 2025-02-16 17:34:09.642603+00:00
#
#    subscription_name            publisher publisher_deal_id
# 0         EM_VETS_19    EM Vets Charlotte      14582726-118
# 1          EM_VETS_1      EM Vets Atlanta      14582726-100
# 2          EM_VETS_1      EM Vets Atlanta      14582726-100
# 4         EM_VETS_19    EM Vets Charlotte      14582726-118
# 5         EM_VETS_19    EM Vets Charlotte      14582726-118
# 6         EM_VETS_19    EM Vets Charlotte      14582726-118
# 7          EM_VETS_3  EM Vets Los Angeles      14582726-102
# 8         EM_VETS_19    EM Vets Charlotte      14582726-118
# 9         EM_VETS_12      EM Vets Chicago      14582726-111
# 10        EM_VETS_19    EM Vets Charlotte      14582726-118
# 11         EM_VETS_4       EM Vets Dallas      14582726-103
# 12        EM_VETS_17   EM Vets Washington      14582726-116
# 13         EM_VETS_4       EM Vets Dallas      14582726-103
# 14        EM_VETS_15    EM Vets San Diego      14582726-114
# 16        EM_VETS_12      EM Vets Chicago      14582726-111
# 17        EM_VETS_19    EM Vets Charlotte      14582726-118
# 22         EM_VETS_8      EM Vets Seattle      14582726-107
# 23        EM_VETS_19    EM Vets Charlotte      14582726-118
# 30        EM_VETS_10   EM Vets Birmingham      14582726-109
# 34        EM_VETS_13      EM Vets Detroit      14582726-112
# 35        EM_VETS_14    EM Vets Las Vegas      14582726-113
# 36        EM_VETS_13      EM Vets Detroit      14582726-112
# 37        EM_VETS_13      EM Vets Detroit      14582726-112
# 38        EM_VETS_10   EM Vets Birmingham      14582726-109
# 41         EM_VETS_4       EM Vets Dallas      14582726-103
# 44        EM_VETS_12      EM Vets Chicago      14582726-111
# 51         EM_VETS_4       EM Vets Dallas      14582726-103
# 53        EM_VETS_13      EM Vets Detroit      14582726-112
# 57        EM_VETS_19    EM Vets Charlotte      14582726-118
# 58        EM_VETS_14    EM Vets Las Vegas      14582726-113
# 59         EM_VETS_1      EM Vets Atlanta      14582726-100
# 62        EM_VETS_12      EM Vets Chicago      14582726-111
# 63        EM_VETS_13      EM Vets Detroit      14582726-112
# 64        EM_VETS_19    EM Vets Charlotte      14582726-118
# 65         EM_VETS_4       EM Vets Dallas      14582726-103
# 70        EM_VETS_19    EM Vets Charlotte      14582726-118
# 75        EM_VETS_14    EM Vets Las Vegas      14582726-113
# 76        EM_VETS_12      EM Vets Chicago      14582726-111
# 79        EM_VETS_12      EM Vets Chicago      14582726-111
# 80         EM_VETS_5      EM Vets Orlando      14582726-104
# 81        EM_VETS_14    EM Vets Las Vegas      14582726-113
# 82         EM_VETS_9     EM Vets Portland      14582726-108
# 83        EM_VETS_12      EM Vets Chicago      14582726-111
# 84        EM_VETS_12      EM Vets Chicago      14582726-111
# 85        EM_VETS_19    EM Vets Charlotte      14582726-118
# 86        EM_VETS_10   EM Vets Birmingham      14582726-109
# 89        EM_VETS_13      EM Vets Detroit      14582726-112

# %%
# Quick QA 

# Compute total records
total_records = len(final_filtered_df)

# Compute unique VET_ID count
unique_vet_ids = final_filtered_df["vet_id"].nunique()

# Compute count of missing values per column
missing_values = final_filtered_df.isna().sum()

# Create a summary DataFrame
summary_df = pd.DataFrame({
    "Metric": ["Total Records", "Unique VET_IDs"],
    "Count": [total_records, unique_vet_ids]
})

# Display results
print("Summary Statistics:")
print(summary_df)

print("\nMissing Values per Column:")
print(missing_values)
# Out:
# Summary Statistics:
#            Metric  Count
# 0   Total Records     47
# 1  Unique VET_IDs     36
#
# Missing Values per Column:
# vet_id               0
# vet_id_source        0
# first_name           0
# last_name            0
# city                 4
# state                4
# zip                  0
# specialty            0
# do_not_sell          0
# event                0
# event_timestamp      0
# subscription_name    0
# publisher            0
# publisher_deal_id    0
# dtype: int64
